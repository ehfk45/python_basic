# %%
f = open("score.csv", "r", encoding="utf-8")
print(f.read())
# print(10 / 0)
for line in f

f.close()
# Out:
# 이름,나이,국어,영어
# 홍길동,20,90,85
# 이순신,21,88,90
# 김유신,,95,100
# 강감찬,22,결측,82
# 유관순,19,100,110
# 안중근,150,85,88
# 윤봉길,20,-5,91
# 신사임당,21,92,
# 장보고,18,87,89
# 세종대왕,23,93,94
# 을지문덕,20,91,86
# 허준,21,89,87
# 김구,22,500,92
# 이황,19,84,81
# 이이,20,86,NaN
# 정약용,21,90,88
# 논개,22,88,85
# 계백,20,,84
# 관우,19,97,96
# 장비,20,95,-10
