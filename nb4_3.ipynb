# %%
x = input ("x입력")
y = input ("y입력")

print(int(x)+int(y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 x = input ("x입력")
#       2 y = input ("y입력")
#       3
# ----> 4 print(int(x)+int(y))
#
# ValueError: invalid literal for int() with base 10: ''
