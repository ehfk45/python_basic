# %%
a=10
print(a)
print(type(a))

# %%
# 2. 부동 소수점 수 (float)
b = 3.14
print(b)
print(type(b))

print(0.1 + 0.2)
# Out:
# 3.14
# <class 'float'>
# 0.30000000000000004

# %%
# 3. 복소수 (complex)
c = 3 + 4j
print(c)
print(type(c))
# Out:
# (3+4j)
# <class 'complex'>

# %%
# 4. 논리값 (bool)
d = True
print(d)
print(type(d))
print(3>5)
# Out:
# True
# <class 'bool'>
# False

# %%
# 5. 문자열 (str)
e = "Python"
print(e)
print(type(e))

print(e[1])
# Out:
# Python
# <class 'str'>
# y

# %%
# 6. 리스트 (list)
f = [1, 2, 3]
print(f)
print(type(f))

print(f[1])

f[1] = 'abc'
print(f)
# Out:
# [1, 2, 3]
# <class 'list'>
# 2
# [1, 'abc', 3]

# %%
# 7. 튜플 (tuple)
g = (1, 2, 3)
print(g)
print(type(g))

print(g[1])

#  g[1] = 9
# Out:
# (1, 2, 3)
# <class 'tuple'>
# 2

# %%
# 8. 딕셔너리 (dict)
h = {"id": "admin" , "pw" : "1234"}
print(h)
print(type(h))

print(h["id"])

h["pw"] = "0000"
print(h)
# Out:
# {'id': 'admin', 'pw': '1234'}
# <class 'dict'>
# admin
# {'id': 'admin', 'pw': '0000'}

# %%
# 9. 집합 (set)
i = {1, 2, 3}
print(i)
print(type(i))

# %%
# 10. 범위 (range)
j = range(0, 5)
print(j)
print(type(j))

print(list(j))
# Out:
# range(0, 5)
# <class 'range'>
# [0, 1, 2, 3, 4]

# %%
# 14. 함수 (function)
def hello():
    print("Hello")
