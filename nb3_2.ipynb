# %%
print(True and False)   # False
print(True or False)    # True
print(not True)         # False

print(10>5 and 10 == 7)

# %%
a = 5
b = 2

print(a + b)   # 7
print(a // b)  # 2
print(a % b)   # 1
print(5 ** 2)
# Out:
# 7
# 2
# 1
# 25
