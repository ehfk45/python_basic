# %%
students = [
    {"이름": "홍길동", "점수": 90},
    {"이름": "김철수", "점수": 85},
    {"이름": "이영희", "점수": 95}
]

print(students)

print(len(students))  # 학생 수 출력
# Out:
# [{'이름': '홍길동', '점수': 90}, {'이름': '김철수', '점수': 85}, {'이름': '이영희', '점수': 95}]
