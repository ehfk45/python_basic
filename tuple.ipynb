# %%
t = (2,4) #불변타입 리스트
print(t)
print(t[0]) #인덱싱
# Out:
# (2, 4)

# %%
t = 1, 3, 5 # 팩킹 실행
print(t) 

print(type(t)) #타입 확인

x, y, z = t # 언팩킹 실행
print(x, y, z)

a, b = [3,6] #(3,6) 변경 후 언팩킹이 발생
print(a, b)
# Out:
# (1, 3, 5)
# <class 'tuple'>
# 1 3 5
