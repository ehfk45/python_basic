# %%
import datetime
import time

# %%
now = datetime.datetime.now()
print(now)
# Out:
# 2026-07-02 12:47:58.026919

# %%
print(now.year)
print(now.month)
print(now.day)
# Out:
# 2026
# 7
# 2

# %%
today = datetime.date.today()
print(today)
