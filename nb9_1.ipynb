# %%
def add(a,b):  # 변수 -> 매개변수
    return a + b # return 함수종료키워드

add2 = add

print(add)
print(add2)


print(add(1,3))
r1 = add(10,20)
print(r1 * 100)

r2 = add2('abc','xyz')
print(r2)



def test():
    return

r3 = test()

print(r3)
# Out:
# <function add at 0x000001F630EB4220>
# <function add at 0x000001F630EB4220>
# 4
# 3000
# abcxyz
# None

# %%
if True:
    x = 10

print(x)
# Out:
# 10

# %%
def test(a): # 지역변수 : a(매개변수) , x
    x = 100 + a
    print(x)


print(x)
print(a)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       3     print(x)
#       4
#       5
#       6 print(x)
# ----> 7 print(a)
#       8
#
# NameError: name 'a' is not defined
