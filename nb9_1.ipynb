# %%
def add(a,b):
    return a + b

add2 = add

print(add)
print(add2)


print(add(1,3))
# Out:
# <function add at 0x000001F630DCD440>
# <function add at 0x000001F630DCD440>
# <function add at 0x000001F630DCD440>
